# %%
#!pip install pandas
#!pip install klib

# %%
# %precision 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import klib
import sklearn

print(pd.__package__ ,pd.__version__)
print(np.__package__ ,np.__version__)
print(sns.__package__ ,sns.__version__)
print(klib.__package__ ,klib.__version__)
print(sklearn.__package__ ,sklearn.__version__)
# Out:
# pandas 1.2.1
# numpy 1.20.0
# seaborn 0.11.1
# klib 0.1.5
# sklearn 0.24.1
